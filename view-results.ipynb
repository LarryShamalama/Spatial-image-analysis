# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

# %config InlineBackend.figure_format = 'retina'
plt.style.use('seaborn-darkgrid')

# %%
phi_values = np.load('results/phi_values.npy')
phi_values.shape
# Out:
# (10000, 784)

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
x_train = x_train/255
x_test  = x_test/255

def plot(image, figsize=(16, 7)):
    
    plt.figure(figsize=figsize)
    plt.imshow(image, cmap='Greys')

# %%
dummy = x_train[12]
plot(dummy, figsize=(10, 5))
_ = plt.title('Label: ' + str(y_train[12]))

# %%
plot(np.mean(phi_values, axis=0).reshape(28, 28))

# %%
plot(np.std(phi_values, axis=0).reshape(28, 28))

# %%
from scipy.sparse import csr_matrix

# %%
csr_matrix(np.zeros((4, 5)))
# Out:
# <4x5 sparse matrix of type '<class 'numpy.float64'>'
# 	with 0 stored elements in Compressed Sparse Row format>
